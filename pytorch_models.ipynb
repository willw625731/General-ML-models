# %%
import torch
from torch import nn
import torch.nn.functional as F


class Perceptron(nn.Module):
    def __init__(self):
        super().__init()
        self.w1 = nn.Parameter(torch.empty(in_dim, out_dim))
        self.b1 = nn.Parameter(torch.zeros(out_dim))
        
    def forward(self, x):
        out = x @ self.w1 + self.b1
        return out
        
# For regression activation at last layer is usually linear
class MLP_Regression(nn.Module):
    def __init__(self):
        super().__init()
        self.w1 = nn.Parameter(torch.empty(in_dim, h1_dim))
        self.w2 = nn.Parameter(torch.empty(h1_dim, out_dim))
        self.b1 = nn.Parameter(torch.zeros(h1_dim))
        self.b2 = nn.Parameter(torch.zeros(out_dim))
        
        self.act = activation
        
    def forward(self, x):
        out = self.act(x @ self.w1 + self.b1)
        out = out @ self.w2 + self.b2
        return out
        
# For classification activation at last layer is usually        
class MLP_Classification(nn.Module):
    def __init__(self):
        super().__init()
        self.w1 = nn.Parameter(torch.empty(in_dim, h1_dim))
        self.w2 = nn.Parameter(torch.empty(h1_dim, out_dim))
        self.b1 = nn.Parameter(torch.zeros(h1_dim))
        self.b2 = nn.Parameter(torch.zeros(out_dim))
        
        self.act = activation
        
    def forward(self, x):
        out = self.act(x @ self.w1 + self.b1)
        out = F.softmax(out @ self.w2 + self.b2)
        return out
        

class NN(nn.Module):
    def __init__(self):
        super().__init()
        self.w1 = nn.Parameter(torch.empty(in_dim, h1_dim))
        self.w2 = nn.Parameter(torch.empty(h1_dim, h2_dim))
        self.w3 = nn.Parameter(torch.empty(h2_dim, out_dim))
        self.b1 = nn.Parameter(torch.zeros(h1_dim))
        self.b2 = nn.Parameter(torch.zeros(h2_dim))
        self.b3 = nn.Parameter(torch.zeros(out_dim))
        
        self.act = activation
        
    def forward(self, x):
        out = self.act(x @ self.w1 + self.b1)
        out = self.act(out @ self.w2 + self.b2)
        out = out @ self.w3 + self.b3
        return out
        
        
class CNN(nn.Module):
    def __init__(self):
        super().__init()
        
        
class Multi_Channel_CNN(nn.Module):
    def __init__(self):
        super().__init()
        
        
class nD_CNN(nn.Module):
    def __init__(self):
        super().__init()
        
        
class one_by_one_CNN(nn.Module):
    def __init__(self):
        super().__init()
        
        
class Transpose_CNN(nn.Module):
    def __init__(self):
        super().__init()
        
        
class Separable_CNN(nn.Module):
    def __init__(self):
        super().__init()
        
        
class Flattened_CNN(nn.Module):
    def __init__(self):
        super().__init()
        
        
class Grouped_CNN(nn.Module):
    def __init__(self):
        super().__init()
        
        
class ShuffledGrouped_CNN(nn.Module):
    def __init__(self):
        super().__init()
        
        
class PointwiseGrouped_CNN(nn.Module):
    def __init__(self):
        super().__init()
        
        
class Residual_CNN(nn.Module):
    def __init__(self):
        super().__init()
        
        
class Dense_CNN(nn.Module):
    def __init__(self):
        super().__init()
        
                
class Vanilla_AE(nn.Module):
    def __init__(self):
        super().__init()
        
        
class Multilayer_AE(nn.Module):
    def __init__(self):
        super().__init()
        
        
class Sparse_AE(nn.Module):
    def __init__(self):
        super().__init()
        
        
class Denoising_AE(nn.Module):
    def __init__(self):
        super().__init()
        
        
class Convolutional_AE(nn.Module):
    def __init__(self):
        super().__init()
        
        
class Variational_AE(nn.Module):
    def __init__(self):
        super().__init()
        
        
class Undercomplete_AE(nn.Module):
    def __init__(self):
        super().__init()
        
        
class Residual_NN(nn.Module):
    def __init__(self):
        super().__init()
        
        
class Dense_NN(nn.Module):
    def __init__(self):
        super().__init()
        
        
class GAN(nn.Module):
    def __init__(self):
        super().__init()
        
        
class RNN_Model(nn.Module):
    def __init__(self):
        super().__init()
        
        
class LSTM_Model(nn.Module):
    def __init__(self):
        super().__init()
        
        
class GRU_Model(nn.Module):
    def __init__(self):
        super().__init()
        
        
class ReinforcementLearning_Model(nn.Module):
    def __init__(self):
        super().__init()
        
        
class Transformer(nn.Module):
    def __init__(self):
        super().__init()
        
        
class Transformer_Encoder(nn.Module):
    def __init__(self):
        super().__init()
        
        
class Transformer_Decoder(nn.Module):
    def __init__(self):
        super().__init()
        
        
class Attention(nn.Module):
    def __init__(self):
        super().__init()
